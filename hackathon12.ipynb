# %% [markdown]
# <a href="https://colab.research.google.com/github/tejaswiniii-11/Team33_Sustainability/blob/main/hackathon12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import pandas as pd

# %%
folder_path = "/content/wind_power_data"

# %%
wind_power_files = [
    "air_temperature_2019.xlsx", "air_temperature_2020.xlsx", "air_temperature_2021.xlsx", "air_temperature_2022.xlsx", "air_temperature_2023.xlsx",
    "power_gen_2019.xlsx", "power_gen_2020.xlsx", "power_gen_2021.xlsx", "power_gen_2022.xlsx", "power_gen_2023.xlsx",
    "pressure_2019.xlsx", "pressure_2020.xlsx", "pressure_2021.xlsx", "pressure_2022.xlsx", "pressure_2023.xlsx",
    "wind_speed_2019.xlsx", "wind_speed_2020.xlsx", "wind_speed_2021.xlsx", "wind_speed_2022.xlsx", "wind_speed_2023.xlsx"
]

# %%
def analyze_wind_power_dataset(files):
    for file in files:
        print("Analyzing file:", file)
        if file.endswith(".xlsx"):
            df = pd.read_excel(os.path.join(folder_path, file))
        elif file.endswith(".csv"):
            df = pd.read_csv(os.path.join(folder_path, file))
        print("Shape:", df.shape)
        print("Columns:", df.columns.tolist())
        print("Missing Values:")
        print(df.isnull().sum())
        print("Basic Statistics:")
        print(df.describe())
        print("\n")

# %%
analyze_wind_power_dataset(wind_power_files)
# Out:
# Analyzing file: air_temperature_2019.xlsx
# Shape: (8759, 2)
# Columns: ['DateTime', 'Air temperature | (°C)']
# Missing Values:
# DateTime                  0
# Air temperature | (°C)    0
# dtype: int64
# Basic Statistics:
#                             DateTime  Air temperature | (°C)
# count                           8759             8759.000000
# mean   2019-07-02 12:00:00.005765376               16.135669
# min              2019-01-01 01:00:00               -9.060000
# 25%              2019-04-02 06:30:00                8.387000
# 50%              2019-07-02 12:00:00               17.536000
# 75%              2019-10-01 17:30:00               23.716500
# max              2019-12-31 23:00:00               38.340000
# std                              NaN               10.016988
#
#
# Analyzing file: air_temperature_2020.xlsx
# Shape: (8784, 2)
# Columns: ['DateTime', 'Air temperature | (°C)']
# Missing Values:
# DateTime                  0
# Air temperature | (°C)    0
# dtype: int64
# Basic Statistics:
#                   DateTime  Air temperature | (°C)
# count                 8784             8784.000000
# mean   2020-07-01 23:30:00               14.927488
# min    2020-01-01 00:00:00              -11.577000
# 25%    2020-04-01 11:45:00                7.351250
# 50%    2020-07-01 23:30:00               16.175000
# 75%    2020-10-01 11:15:00               22.617250
# max    2020-12-31 23:00:00               35.737000
# std                    NaN                9.940777
#
#
# Analyzing file: air_temperature_2021.xlsx
# Shape: (8760, 2)
# Columns: ['DateTime', 'Air temperature | (°C)']
# Missing Values:
# DateTime                  0
# Air temperature | (°C)    0
# dtype: int64
# Basic Statistics:
#                   DateTime  Air temperature | (°C)
# count                 8760             8760.000000
# mean   2021-07-02 11:30:00               14.877481
# min    2021-01-01 00:00:00              -14.066000
# 25%    2021-04-02 05:45:00                7.524500
# 50%    2021-07-02 11:30:00               16.116500
# 75%    2021-10-01 17:15:00               22.085500
# max    2021-12-31 23:00:00               35.235000
# std                    NaN                9.591484
#
#
# Analyzing file: air_temperature_2022.xlsx
# Shape: (8760, 2)
# Columns: ['DateTime', 'Air temperature | (°C)']
# Missing Values:
# DateTime                  0
# Air temperature | (°C)    0
# dtype: int64
# Basic Statistics:
#                   DateTime  Air temperature | (°C)
# count                 8760             8760.000000
# mean   2022-07-02 11:30:00               14.720040
# min    2022-01-01 00:00:00              -12.634000
# 25%    2022-04-02 05:45:00                5.719500
# 50%    2022-07-02 11:30:00               15.891000
# 75%    2022-10-01 17:15:00               23.723500
# max    2022-12-31 23:00:00               36.039000
# std                    NaN               11.181997
#
#
# Analyzing file: air_temperature_2023.xlsx
# Shape: (8760, 2)
# Columns: ['DateTime', 'Air temperature | (°C)']
# Missing Values:
# DateTime                  0
# Air temperature | (°C)    0
# dtype: int64
# Basic Statistics:
#                   DateTime  Air temperature | (°C)
# count                 8760             8760.000000
# mean   2023-07-02 11:30:00               16.256839
# min    2023-01-01 00:00:00               -7.306000
# 25%    2023-04-02 05:45:00                9.785000
# 50%    2023-07-02 11:30:00               16.660000
# 75%    2023-10-01 17:15:00               22.999000
# max    2023-12-31 23:00:00               38.805000
# std                    NaN                9.085186
#
#
# Analyzing file: power_gen_2019.xlsx
# Shape: (8759, 2)
# Columns: ['DateTime', 'Power generated by system | (MW)']
# Missing Values:
# DateTime                            0
# Power generated by system | (MW)    0
# dtype: int64
# Basic Statistics:
#                             DateTime  Power generated by system | (MW)
# count                           8759                       8759.000000
# mean   2019-07-02 12:00:00.005765376                         14.501010
# min              2019-01-01 01:00:00                          0.000000
# 25%              2019-04-02 06:30:00                          0.000000
# 50%              2019-07-02 12:00:00                          7.977500
# 75%              2019-10-01 17:30:00                         24.323600
# max              2019-12-31 23:00:00                         59.918300
# std                              NaN                         16.528013
#
#
# Analyzing file: power_gen_2020.xlsx
# Shape: (8784, 2)
# Columns: ['DateTime', 'Power generated by system | (MW)']
# Missing Values:
# DateTime                            0
# Power generated by system | (MW)    0
# dtype: int64
# Basic Statistics:
#                   DateTime  Power generated by system | (MW)
# count                 8784                       8784.000000
# mean   2020-07-01 23:30:00                         16.373224
# min    2020-01-01 00:00:00                          0.000000
# 25%    2020-04-01 11:45:00                          0.000000
# 50%    2020-07-01 23:30:00                          8.802515
# 75%    2020-10-01 11:15:00                         28.787650
# max    2020-12-31 23:00:00                         60.679200
# std                    NaN                         18.173043
#
#
# Analyzing file: power_gen_2021.xlsx
# Shape: (8760, 2)
# Columns: ['DateTime', 'Power generated by system | (MW)']
# Missing Values:
# DateTime                            0
# Power generated by system | (MW)    0
# dtype: int64
# Basic Statistics:
#                   DateTime  Power generated by system | (MW)
# count                 8760                       8760.000000
# mean   2021-07-02 11:30:00                         15.328707
# min    2021-01-01 00:00:00                          0.000000
# 25%    2021-04-02 05:45:00                          1.080248
# 50%    2021-07-02 11:30:00                          8.411275
# 75%    2021-10-01 17:15:00                         25.279750
# max    2021-12-31 23:00:00                         60.870800
# std                    NaN                         17.204382
#
#
# Analyzing file: power_gen_2022.xlsx
# Shape: (8760, 2)
# Columns: ['DateTime', 'Power generated by system | (MW)']
# Missing Values:
# DateTime                            0
# Power generated by system | (MW)    0
# dtype: int64
# Basic Statistics:
#                   DateTime  Power generated by system | (MW)
# count                 8760                       8760.000000
# mean   2022-07-02 11:30:00                         13.607228
# min    2022-01-01 00:00:00                          0.000000
# 25%    2022-04-02 05:45:00                          0.000000
# 50%    2022-07-02 11:30:00                          5.639445
# 75%    2022-10-01 17:15:00                         22.768375
# max    2022-12-31 23:00:00                         61.245400
# std                    NaN                         16.717288
#
#
# Analyzing file: power_gen_2023.xlsx
# Shape: (8760, 2)
# Columns: ['DateTime', 'Power generated by system | (MW)']
# Missing Values:
# DateTime                            0
# Power generated by system | (MW)    0
# dtype: int64
# Basic Statistics:
#                   DateTime  Power generated by system | (MW)
# count                 8760                       8760.000000
# mean   2023-07-02 11:30:00                         14.355800
# min    2023-01-01 00:00:00                          0.000000
# 25%    2023-04-02 05:45:00                          0.000000
# 50%    2023-07-02 11:30:00                          6.384700
# 75%    2023-10-01 17:15:00                         23.135725
# max    2023-12-31 23:00:00                         60.441700
# std                    NaN                         17.375531
#
#
# Analyzing file: pressure_2019.xlsx
# Shape: (8759, 2)
# Columns: ['DateTime', 'Pressure | (atm)']
# Missing Values:
# DateTime            0
# Pressure | (atm)    0
# dtype: int64
# Basic Statistics:
#                             DateTime  Pressure | (atm)
# count                           8759       8759.000000
# mean   2019-07-02 12:00:00.005765376          0.982109
# min              2019-01-01 01:00:00          0.960741
# 25%              2019-04-02 06:30:00          0.978926
# 50%              2019-07-02 12:00:00          0.981726
# 75%              2019-10-01 17:30:00          0.985447
# max              2019-12-31 23:00:00          0.998478
# std                              NaN          0.004997
#
#
# Analyzing file: pressure_2020.xlsx
# Shape: (8784, 2)
# Columns: ['DateTime', 'Pressure | (atm)']
# Missing Values:
# DateTime            0
# Pressure | (atm)    0
# dtype: int64
# Basic Statistics:
#                   DateTime  Pressure | (atm)
# count                 8784       8784.000000
# mean   2020-07-01 23:30:00          0.981588
# min    2020-01-01 00:00:00          0.960687
# 25%    2020-04-01 11:45:00          0.978055
# 50%    2020-07-01 23:30:00          0.981021
# 75%    2020-10-01 11:15:00          0.985469
# max    2020-12-31 23:00:00          1.005580
# std                    NaN          0.005882
#
#
# Analyzing file: pressure_2021.xlsx
# Shape: (8760, 2)
# Columns: ['DateTime', 'Pressure | (atm)']
# Missing Values:
# DateTime            0
# Pressure | (atm)    0
# dtype: int64
# Basic Statistics:
#                   DateTime  Pressure | (atm)
# count                 8760       8760.000000
# mean   2021-07-02 11:30:00          0.981093
# min    2021-01-01 00:00:00          0.958598
# 25%    2021-04-02 05:45:00          0.977582
# 50%    2021-07-02 11:30:00          0.980946
# 75%    2021-10-01 17:15:00          0.984393
# max    2021-12-31 23:00:00          1.004150
# std                    NaN          0.005580
#
#
# Analyzing file: pressure_2022.xlsx
# Shape: (8760, 2)
# Columns: ['DateTime', 'Pressure | (atm)']
# Missing Values:
# DateTime            0
# Pressure | (atm)    0
# dtype: int64
# Basic Statistics:
#                   DateTime  Pressure | (atm)
# count                 8760       8760.000000
# mean   2022-07-02 11:30:00          0.980502
# min    2022-01-01 00:00:00          0.961480
# 25%    2022-04-02 05:45:00          0.977388
# 50%    2022-07-02 11:30:00          0.980571
# 75%    2022-10-01 17:15:00          0.983653
# max    2022-12-31 23:00:00          0.997472
# std                    NaN          0.005297
#
#
# Analyzing file: pressure_2023.xlsx
# Shape: (8760, 2)
# Columns: ['DateTime', 'Pressure | (atm)']
# Missing Values:
# DateTime            0
# Pressure | (atm)    0
# dtype: int64
# Basic Statistics:
#                   DateTime  Pressure | (atm)
# count                 8760       8760.000000
# mean   2023-07-02 11:30:00          0.981141
# min    2023-01-01 00:00:00          0.961137
# 25%    2023-04-02 05:45:00          0.977768
# 50%    2023-07-02 11:30:00          0.980738
# 75%    2023-10-01 17:15:00          0.984544
# max    2023-12-31 23:00:00          0.996449
# std                    NaN          0.005206
#
#
# Analyzing file: wind_speed_2019.xlsx
# Shape: (8759, 2)
# Columns: ['DateTime', 'Wind speed | (m/s)']
# Missing Values:
# DateTime              0
# Wind speed | (m/s)    0
# dtype: int64
# Basic Statistics:
#                             DateTime  Wind speed | (m/s)
# count                           8759         8759.000000
# mean   2019-07-02 12:00:00.005765376            5.916880
# min              2019-01-01 01:00:00            0.140000
# 25%              2019-04-02 06:30:00            3.565500
# 50%              2019-07-02 12:00:00            5.813000
# 75%              2019-10-01 17:30:00            8.110000
# max              2019-12-31 23:00:00           16.540000
# std                              NaN            2.892041
#
#
# Analyzing file: wind_speed_2020.xlsx
# Shape: (8784, 2)
# Columns: ['DateTime', 'Wind speed | (m/s)']
# Missing Values:
# DateTime              0
# Wind speed | (m/s)    0
# dtype: int64
# Basic Statistics:
#                   DateTime  Wind speed | (m/s)
# count                 8784         8784.000000
# mean   2020-07-01 23:30:00            6.181576
# min    2020-01-01 00:00:00            0.233000
# 25%    2020-04-01 11:45:00            3.584000
# 50%    2020-07-01 23:30:00            5.970000
# 75%    2020-10-01 11:15:00            8.594250
# max    2020-12-31 23:00:00           18.233000
# std                    NaN            3.149038
#
#
# Analyzing file: wind_speed_2021.xlsx
# Shape: (8760, 2)
# Columns: ['DateTime', 'Wind speed | (m/s)']
# Missing Values:
# DateTime              0
# Wind speed | (m/s)    0
# dtype: int64
# Basic Statistics:
#                   DateTime  Wind speed | (m/s)
# count                 8760         8760.000000
# mean   2021-07-02 11:30:00            6.143257
# min    2021-01-01 00:00:00            0.238000
# 25%    2021-04-02 05:45:00            3.881250
# 50%    2021-07-02 11:30:00            5.900000
# 75%    2021-10-01 17:15:00            8.230000
# max    2021-12-31 23:00:00           19.725000
# std                    NaN            2.954194
#
#
# Analyzing file: wind_speed_2022.xlsx
# Shape: (8760, 2)
# Columns: ['DateTime', 'Wind speed | (m/s)']
# Missing Values:
# DateTime              0
# Wind speed | (m/s)    0
# dtype: int64
# Basic Statistics:
#                   DateTime  Wind speed | (m/s)
# count                 8760         8760.000000
# mean   2022-07-02 11:30:00            5.668226
# min    2022-01-01 00:00:00            0.179000
# 25%    2022-04-02 05:45:00            3.152500
# 50%    2022-07-02 11:30:00            5.360000
# 75%    2022-10-01 17:15:00            7.908250
# max    2022-12-31 23:00:00           16.633000
# std                    NaN            3.034879
#
#
# Analyzing file: wind_speed_2023.xlsx
# Shape: (8760, 2)
# Columns: ['DateTime', 'Wind speed | (m/s)']
# Missing Values:
# DateTime              0
# Wind speed | (m/s)    0
# dtype: int64
# Basic Statistics:
#                   DateTime  Wind speed | (m/s)
# count                 8760         8760.000000
# mean   2023-07-02 11:30:00            5.884426
# min    2023-01-01 00:00:00            0.281000
# 25%    2023-04-02 05:45:00            3.539750
# 50%    2023-07-02 11:30:00            5.522000
# 75%    2023-10-01 17:15:00            7.987750
# max    2023-12-31 23:00:00           16.876000
# std                    NaN            2.995443

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def visualize_data(df, column_name):
    plt.figure(figsize=(10, 6))
    sns.histplot(df[column_name], bins=20, kde=True)
    plt.title(f"Distribution of {column_name}")
    plt.xlabel(column_name)
    plt.ylabel("Frequency")
    plt.show()

# %%
for year in range(2019, 2024):
    file_name = f"air_temperature_{year}.xlsx"
    df = pd.read_excel(os.path.join(folder_path, file_name))
    visualize_data(df, 'Air temperature | (°C)')

# %%
for year in range(2019, 2024):
    file_name = f"power_gen_{year}.xlsx"
    df = pd.read_excel(os.path.join(folder_path, file_name))
    visualize_data(df, 'Power generated by system | (MW)')

# Analyzing pressure data
for year in range(2019, 2024):
    file_name = f"pressure_{year}.xlsx"
    df = pd.read_excel(os.path.join(folder_path, file_name))
    visualize_data(df, 'Pressure | (atm)')

# Analyzing wind speed data
for year in range(2019, 2024):
    file_name = f"wind_speed_{year}.xlsx"
    df = pd.read_excel(os.path.join(folder_path, file_name))
    visualize_data(df, 'Wind speed | (m/s)')

# %%
def analyze_wind_power_dataset(files):
    for file in files:
        print("Analyzing file:", file)
        if file.endswith(".xlsx"):
            df = pd.read_excel(os.path.join(folder_path, file))
        elif file.endswith(".csv"):
            df = pd.read_csv(os.path.join(folder_path, file))

        # Check data types and consistency of DateTime columns
        if 'DateTime' in df.columns:
            print("Data Types:")
            print(df.dtypes)
            print("\n")
            print("Checking consistency of DateTime column:")
            print("Minimum DateTime:", df['DateTime'].min())
            print("Maximum DateTime:", df['DateTime'].max())
            print("\n")
        else:
            print("DateTime column not found in the dataset.")

        print("Shape:", df.shape)
        print("Columns:", df.columns.tolist())
        print("Missing Values:")
        print(df.isnull().sum())
        print("Basic Statistics:")
        print(df.describe())
        print("\n")

# Execute the function
analyze_wind_power_dataset(wind_power_files)
